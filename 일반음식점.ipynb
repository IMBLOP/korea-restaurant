# %%
import pandas as pd
df=pd.read_csv('fulldata.csv', encoding='cp949')

df = df[['상세영업상태코드', '소재지전체주소', '도로명전체주소', '사업장명', '업태구분명', '위생업태명']]

df = df[df.상세영업상태코드 == 1]
df = df.drop('상세영업상태코드', axis=1)

df = df.reset_index(drop=True)
df.to_csv('data.csv')

print(df)
# Out:
# <ipython-input-11-cd761f26363c>:2: DtypeWarning: Columns (11,27,39,41,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('fulldata.csv', encoding='cp949')
#                                           소재지전체주소  \
# 0                     경기도 하남시 선동 427 미사강변 더샵 리버포레
# 1       인천광역시 중구 운서동 3094-2 더 예스 포레스트 2층 205,206호
# 2                              부산광역시 동래구 온천동 96-5
# 3                부산광역시 동래구 낙민동 326 포레나 동래 201동 7호
# 4                            충청북도 증평군 증평읍 송산리 881
# ...                                           ...
# 697984                       광주광역시 서구 용두동 306번지 1
# 697985                        광주광역시 남구 양림동 374 2층
# 697986               광주광역시 남구 월산동 1048-182번지 (1층)
# 697987                  광주광역시 서구 화정동 332-9번지 (1층)
# 697988                    광주광역시 서구 화정동 70-61 (1층)
#
#                                                  도로명전체주소                사업장명  \
# 0         경기도 하남시 미사강변북로 65-1, 미사강변 더샵 리버포레 1층 101호 (선동)  33떡볶이&꼬마김밥 미사리버포레점
# 1         인천광역시 중구 흰바위로 113, 더 예스 포레스트 2층 205,206호 (운서동)            중화요리 미식재
# 2                   부산광역시 동래구 금강공원로26번길 29, 2층 일부호 (온천동)       웨이브라운지 바(Bar)
# 3       부산광역시 동래구 온천천로339번길 51, 201동 1층 7호 (낙민동, 포레나 동래)        4242샌드위치 동래점
# 4                                  충청북도 증평군 증평읍 송산로5길 37           백세장수촌 증평점
# ...                                                  ...                 ...
# 697984                       광주광역시 서구 용두난산길 46, 1층 (용두동)                원아가든
# 697985                         광주광역시 남구 제중로 39, 2층 (양림동)                 뚱스넥
# 697986                       광주광역시 남구 군분로 26-1, 1층 (월산동)             갈비명가아라네
# 697987                  광주광역시 서구 월드컵4강로116번길 5, 1층 (화정동)                승진이네
# 697988                    광주광역시 서구 내방로350번길 10, 1층 (화정동)           화정명가 광주본점
#
#         업태구분명  위생업태명
# 0          분식     분식
# 1         중국식    중국식
# 2       호프/통닭  호프/통닭
# 3         경양식    경양식
# 4          한식     한식
# ...       ...    ...
# 697984     한식     한식
# 697985     한식     한식
# 697986     한식     한식
# 697987     한식     한식
# 697988     한식     한식
#
# [697989 rows x 5 columns]

# %%
import pandas as pd
df=pd.read_csv('data_ver1.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)

df['주소'] = df['소재지전체주소'].fillna(df['도로명전체주소']).apply(lambda x: x.split()[0])
df = df.reset_index(drop=True)

df.to_csv('data_ver2.csv')

print(df)
# Out:
#                                           소재지전체주소  \
# 0                     경기도 하남시 선동 427 미사강변 더샵 리버포레
# 1       인천광역시 중구 운서동 3094-2 더 예스 포레스트 2층 205,206호
# 2                              부산광역시 동래구 온천동 96-5
# 3                부산광역시 동래구 낙민동 326 포레나 동래 201동 7호
# 4                            충청북도 증평군 증평읍 송산리 881
# ...                                           ...
# 697984                       광주광역시 서구 용두동 306번지 1
# 697985                        광주광역시 남구 양림동 374 2층
# 697986               광주광역시 남구 월산동 1048-182번지 (1층)
# 697987                  광주광역시 서구 화정동 332-9번지 (1층)
# 697988                    광주광역시 서구 화정동 70-61 (1층)
#
#                                                  도로명전체주소                사업장명  \
# 0         경기도 하남시 미사강변북로 65-1, 미사강변 더샵 리버포레 1층 101호 (선동)  33떡볶이&꼬마김밥 미사리버포레점
# 1         인천광역시 중구 흰바위로 113, 더 예스 포레스트 2층 205,206호 (운서동)            중화요리 미식재
# 2                   부산광역시 동래구 금강공원로26번길 29, 2층 일부호 (온천동)       웨이브라운지 바(Bar)
# 3       부산광역시 동래구 온천천로339번길 51, 201동 1층 7호 (낙민동, 포레나 동래)        4242샌드위치 동래점
# 4                                  충청북도 증평군 증평읍 송산로5길 37           백세장수촌 증평점
# ...                                                  ...                 ...
# 697984                       광주광역시 서구 용두난산길 46, 1층 (용두동)                원아가든
# 697985                         광주광역시 남구 제중로 39, 2층 (양림동)                 뚱스넥
# 697986                       광주광역시 남구 군분로 26-1, 1층 (월산동)             갈비명가아라네
# 697987                  광주광역시 서구 월드컵4강로116번길 5, 1층 (화정동)                승진이네
# 697988                    광주광역시 서구 내방로350번길 10, 1층 (화정동)           화정명가 광주본점
#
#         업태구분명  위생업태명     주소
# 0          분식     분식    경기도
# 1         중국식    중국식  인천광역시
# 2       호프/통닭  호프/통닭  부산광역시
# 3         경양식    경양식  부산광역시
# 4          한식     한식   충청북도
# ...       ...    ...    ...
# 697984     한식     한식  광주광역시
# 697985     한식     한식  광주광역시
# 697986     한식     한식  광주광역시
# 697987     한식     한식  광주광역시
# 697988     한식     한식  광주광역시
#
# [697989 rows x 6 columns]

# %%
import pandas as pd
df=pd.read_csv('data_ver2.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)

df = df[df.주소 == '서울특별시']

df['세부주소'] = df['소재지전체주소'].fillna(df['도로명전체주소']).apply(lambda x: x.split()[0] + ' ' + x.split()[1])
df = df.reset_index(drop=True)

df.to_csv('data_seoul.csv')

print(df)
# Out:
#                                  소재지전체주소  \
# 0                   서울특별시 마포구 서교동 346-34
# 1                   서울특별시 마포구 망원동 416-14
# 2                   서울특별시 마포구 서교동 332-27
# 3               서울특별시 마포구 연남동 515-12 미스바
# 4                    서울특별시 강북구 우이동 72-65
# ...                                  ...
# 124808  서울특별시 양천구 신정동 889-15 춘당아네시스 101호
# 124809         서울특별시 양천구 신월동 534-25 정세빌딩
# 124810               서울특별시 양천구 신월동 60-33
# 124811              서울특별시 강북구 수유동 229-46
# 124812               서울특별시 강북구 번동 415-19
#
#                                          도로명전체주소             사업장명 업태구분명 위생업태명  \
# 0               서울특별시 마포구 와우산로23길 48, 2,3층 (서교동)           (주)소과당    기타    기타
# 1                    서울특별시 마포구 망원로4길 3, 2층 (망원동)            카페 화로    기타    기타
# 2              서울특별시 마포구 와우산로29바길 11-3, 2층 (서교동)        럭키데이즈 홀덤펍    기타    기타
# 3         서울특별시 마포구 연남로3길 10, 1층 101호 (연남동, 미스바)      한촉(HANCHOC)    기타    기타
# 4                    서울특별시 강북구 삼양로 520, 2층 (우이동)           시트러스소다    한식    한식
# ...                                          ...              ...   ...   ...
# 124808  서울특별시 양천구 신정중앙로19길 7, 101호 (신정동, 춘당아네시스)      젤로디(Gelo:D)    기타    기타
# 124809          서울특별시 양천구 신월로 191, 정세빌딩 1층 (신월동)     목돈칠이(72) 신월점    한식    한식
# 124810                서울특별시 양천구 화곡로 96, 1층 (신월동)  전주가콩나물국밥전문점 화곡점    한식    한식
# 124811           서울특별시 강북구 도봉로87길 11, 지하1층 (수유동)              미라클    기타    기타
# 124812             서울특별시 강북구 오패산로 396-1, 1층 (번동)         분식집 막내아들    한식    한식
#
#            주소       세부주소
# 0       서울특별시  서울특별시 마포구
# 1       서울특별시  서울특별시 마포구
# 2       서울특별시  서울특별시 마포구
# 3       서울특별시  서울특별시 마포구
# 4       서울특별시  서울특별시 강북구
# ...       ...        ...
# 124808  서울특별시  서울특별시 양천구
# 124809  서울특별시  서울특별시 양천구
# 124810  서울특별시  서울특별시 양천구
# 124811  서울특별시  서울특별시 강북구
# 124812  서울특별시  서울특별시 강북구
#
# [124813 rows x 7 columns]

# %%
import pandas as pd
df=pd.read_csv('data_ver2.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)

df = df[df.주소 == '경기도']

df['세부주소'] = df['소재지전체주소'].fillna(df['도로명전체주소']).apply(lambda x: x.split()[0] + ' ' + x.split()[1])
df = df.reset_index(drop=True)

df.to_csv('data_gyeonggi.csv')

print(df)
# Out:
#                                   소재지전체주소  \
# 0             경기도 하남시 선동 427 미사강변 더샵 리버포레
# 1           경기도 안산시 상록구 수암동 499-1 1층 101호
# 2       경기도 안산시 상록구 본오동 873-7 리치스빌딩 1층 일부
# 3                       경기도 하남시 감일동 514-4
# 4                      경기도 파주시 금릉동 434-10
# ...                                   ...
# 150555        경기도 남양주시 퇴계원면 퇴계원리 255-35번지
# 150556             경기도 남양주시 수동면 지둔리 229번지
# 150557            경기도 남양주시 오남읍 오남리 48-4번지
# 150558          경기도 의정부시 산곡동 686-1 폴리프라자Ⅰ
# 150559            경기도 의정부시 의정부동 440-51 1층
#
#                                                도로명전체주소                사업장명  \
# 0       경기도 하남시 미사강변북로 65-1, 미사강변 더샵 리버포레 1층 101호 (선동)  33떡볶이&꼬마김밥 미사리버포레점
# 1                   경기도 안산시 상록구 원당골1길 6, 1층 101호 (수암동)         국풍설렁탕(수암본점)
# 2                경기도 안산시 상록구 본삼로 51, 리치스빌딩 1층 일부 (본오동)         심야스테이크 상록수점
# 3                       경기도 하남시 감일로 140, 5층 502호 (감일동)                 그늘집
# 4                        경기도 파주시 쇠재안길 66, 1층 일부호 (금릉동)                 밥풀꽃
# ...                                                ...                 ...
# 150555                       경기도 남양주시 퇴계원면 퇴계원로46번길 10              누님부대찌게
# 150556                        경기도 남양주시 수동면 비룡로 1117-22                고향산천
# 150557                      경기도 남양주시 오남읍 진건오남로숫돌2길 6-1              투데이 호프
# 150558        경기도 의정부시 세석로 20, 폴리프라자Ⅰ 지상 1층 101호 (산곡동)        60계 경기의정부고산점
# 150559                경기도 의정부시 신흥로258번길 7, 지상1층 (의정부동)   코제하우스(COZE HOUSE)
#
#         업태구분명  위생업태명   주소      세부주소
# 0          분식     분식  경기도   경기도 하남시
# 1          한식     한식  경기도   경기도 안산시
# 2         경양식    경양식  경기도   경기도 안산시
# 3          기타     기타  경기도   경기도 하남시
# 4          한식     한식  경기도   경기도 파주시
# ...       ...    ...  ...       ...
# 150555     한식     한식  경기도  경기도 남양주시
# 150556     한식     한식  경기도  경기도 남양주시
# 150557  호프/통닭  호프/통닭  경기도  경기도 남양주시
# 150558  호프/통닭  호프/통닭  경기도  경기도 의정부시
# 150559     한식     한식  경기도  경기도 의정부시
#
# [150560 rows x 7 columns]
